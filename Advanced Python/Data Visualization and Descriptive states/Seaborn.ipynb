# %%
import seaborn as sns

# %%
df=sns.load_dataset('tips')

# %%
df.head(50).tail()
# Out:
#     total_bill   tip   sex smoker  day    time  size
# 45       18.29  3.00  Male     No  Sun  Dinner     2
# 46       22.23  5.00  Male     No  Sun  Dinner     2
# 47       32.40  6.00  Male     No  Sun  Dinner     4
# 48       28.55  2.05  Male     No  Sun  Dinner     3
# 49       18.04  3.00  Male     No  Sun  Dinner     2

# %%
sns.distplot(df['total_bill'],bins=10,kde=True,hist=True)

# %%
sns.pairplot(df,hue='sex',kind='scatter')

# %%
sns.scatterplot('total_bill','tip',data=df,hue='sex',size='size',palette='rainbow')

# %%
sns.scatterplot('total_bill','tip',data=df,hue='sex',size='size')

# %%
sns.scatterplot('total_bill','tip',data=df,hue='sex')

# %%
sns.jointplot('total_bill','tip',data=df,color='green')

# %%
sns.jointplot('total_bill','tip',data=df,color='green',kind='kde')

# %%
sns.jointplot('total_bill','tip',data=df,color='green',kind='hex')

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.boxenplot(x='total_bill',data=df,orient='v',hue='size',color='yellow')

# %%
sns.violinplot(x='sex',y='total_bill',data=df,hue='smoker')

# %%
sns.swarmplot(x='sex',y='total_bill',data=df,hue='smoker')

# %%
sns.countplot(x='sex',data=df)

# %%
sns.countplot(x='sex',data=df,hue='smoker')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.countplot(x='sex',data=df,hue='smoker',dodge=False,palette='coolwarm')
plt.show()
