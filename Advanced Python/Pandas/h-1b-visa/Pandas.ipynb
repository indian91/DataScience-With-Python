# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# %matplotlib inline

# %%
s1 = pd.Series([1,2,3,45,56],dtype=float,name='data')

# %%
s1
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3    45.0
# 4    56.0
# Name: data, dtype: float64

# %%
s1[[True,False,True,False,False]]
# Out:
# 0    1.0
# 2    3.0
# Name: data, dtype: float64

# %%
s1[s1.isin([3.0,2.0])]
# Out:
# 1    2.0
# 2    3.0
# Name: data, dtype: float64

# %%
s1[s1>=5.0]
# Out:
# 3    45.0
# 4    56.0
# Name: data, dtype: float64

# %%
s = pd.Series(np.random.randint(10,30,1000))

# %%
s[s>25].unique()
# Out:
# array([26, 27, 29, 28], dtype=int64)

# %%
s1 = s[s>20]

# %%
s1 = s1.value_counts()

# %%
s1.index
# Out:
# Int64Index([29, 25, 21, 24, 23, 27, 22, 28, 26], dtype='int64')

# %%
s1.values
# Out:
# array([59, 54, 53, 49, 48, 47, 47, 46, 45], dtype=int64)

# %%
plt.bar(x=s1.index,height=s1.values)
plt.show()

# %%
date = pd.date_range('20190601',periods=10)

# %%
data = np.random.randint(5,10,10)

# %%
date
# Out:
# DatetimeIndex(['2019-06-01', '2019-06-02', '2019-06-03', '2019-06-04',
#                '2019-06-05', '2019-06-06', '2019-06-07', '2019-06-08',
#                '2019-06-09', '2019-06-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
data
# Out:
# array([9, 8, 5, 7, 6, 7, 9, 9, 6, 9])

# %%
s = pd.Series(data=data,index=date,name='avai')

# %%
s
# Out:
# 2019-06-01    9
# 2019-06-02    8
# 2019-06-03    5
# 2019-06-04    7
# 2019-06-05    6
# 2019-06-06    7
# 2019-06-07    9
# 2019-06-08    9
# 2019-06-09    6
# 2019-06-10    9
# Freq: D, Name: avai, dtype: int32

# %%
s[::2]
# Out:
# 2019-06-01    9
# 2019-06-03    5
# 2019-06-05    6
# 2019-06-07    9
# 2019-06-09    6
# Freq: 2D, Name: avai, dtype: int32

# %%
s['20190606':'20190610':2]
# Out:
# 2019-06-06    7
# 2019-06-08    9
# 2019-06-10    9
# Freq: 2D, Name: avai, dtype: int32

# %%
student = { 

    'name' : [ 'ram','hari','jhon','alice','bob','natasha'],
    'maths' : [ 56,78,np.nan,78,68,89],
    'chemistry':[ 78,89,78,np.nan,56,76],
    'physics' : [ 66,77,88,45,67,np.nan],
    'sex' : pd.Categorical(['male','male','male','female','male','female'])
}

# %%
df = pd.DataFrame(data=student,index=range(1,7))

# %%
df
# Out:
#       name  maths  chemistry  physics     sex
# 1      ram   56.0       78.0     66.0    male
# 2     hari   78.0       89.0     77.0    male
# 3     jhon    NaN       78.0     88.0    male
# 4    alice   78.0        NaN     45.0  female
# 5      bob   68.0       56.0     67.0    male
# 6  natasha   89.0       76.0      NaN  female

# %%
df.shape
# Out:
# (6, 5)

# %%
df.size
# Out:
# 30

# %%
df.dtypes
# Out:
# name           object
# maths         float64
# chemistry     float64
# physics       float64
# sex          category
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 1 to 6
# Data columns (total 5 columns):
# name         6 non-null object
# maths        5 non-null float64
# chemistry    5 non-null float64
# physics      5 non-null float64
# sex          6 non-null category
# dtypes: category(1), float64(3), object(1)
# memory usage: 378.0+ bytes

# %%
df
# Out:
#       name  maths  chemistry  physics     sex
# 1      ram   56.0       78.0     66.0    male
# 2     hari   78.0       89.0     77.0    male
# 3     jhon    NaN       78.0     88.0    male
# 4    alice   78.0        NaN     45.0  female
# 5      bob   68.0       56.0     67.0    male
# 6  natasha   89.0       76.0      NaN  female

# %%
df['maths'][df['maths'].isna()] = 0.0
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#       name  maths  chemistry  physics     sex
# 1      ram   56.0       78.0     66.0    male
# 2     hari   78.0       89.0     77.0    male
# 3     jhon    0.0       78.0     88.0    male
# 4    alice   78.0        NaN     45.0  female
# 5      bob   68.0       56.0     67.0    male
# 6  natasha   89.0       76.0      NaN  female

# %%
col = ['maths','chemistry','physics',]
for each_col in col :
    df[each_col][df[each_col].isna()] = 0
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df
# Out:
#       name  maths  chemistry  physics     sex
# 1      ram   56.0       78.0     66.0    male
# 2     hari   78.0       89.0     77.0    male
# 3     jhon    0.0       78.0     88.0    male
# 4    alice   78.0        0.0     45.0  female
# 5      bob   68.0       56.0     67.0    male
# 6  natasha   89.0       76.0      0.0  female

# %%
df.describe()
# Out:
#            maths  chemistry    physics
# count   6.000000   6.000000   6.000000
# mean   61.500000  62.833333  57.166667
# std    32.110746  32.597035  31.416026
# min     0.000000   0.000000   0.000000
# 25%    59.000000  61.000000  50.250000
# 50%    73.000000  77.000000  66.500000
# 75%    78.000000  78.000000  74.500000
# max    89.000000  89.000000  88.000000

# %%
df[:]
# Out:
#       name  maths  chemistry  physics     sex
# 1      ram   56.0       78.0     66.0    male
# 2     hari   78.0       89.0     77.0    male
# 3     jhon    0.0       78.0     88.0    male
# 4    alice   78.0        0.0     45.0  female
# 5      bob   68.0       56.0     67.0    male
# 6  natasha   89.0       76.0      0.0  female

# %%
df[::2]
# Out:
#    name  maths  chemistry  physics   sex
# 1   ram   56.0       78.0     66.0  male
# 3  jhon    0.0       78.0     88.0  male
# 5   bob   68.0       56.0     67.0  male

# %%
df[['name','sex']][:3] # column selection
# Out:
#    name   sex
# 1   ram  male
# 2  hari  male
# 3  jhon  male

# %%
df.loc[::2,::2]
# Out:
#    name  chemistry   sex
# 1   ram       78.0  male
# 3  jhon       78.0  male
# 5   bob       56.0  male

# %%
df1 = pd.DataFrame(np.random.randint(1,100,20).reshape(5,4),
                   columns=list("ABCD"),
                  index=pd.date_range('20190620',periods=5))

# %%
df1
# Out:
#              A   B   C   D
# 2019-06-20  38  59  76  92
# 2019-06-21  37  85  55  76
# 2019-06-22  74  50  93  52
# 2019-06-23  61  24  56  81
# 2019-06-24  90  70  95  25

# %%
df1.loc[:,:]
# Out:
#              A   B   C   D
# 2019-06-20  38  59  76  92
# 2019-06-21  37  85  55  76
# 2019-06-22  74  50  93  52
# 2019-06-23  61  24  56  81
# 2019-06-24  90  70  95  25

# %%
df1.loc[:,::2]
# Out:
#              A   C
# 2019-06-20  38  76
# 2019-06-21  37  55
# 2019-06-22  74  93
# 2019-06-23  61  56
# 2019-06-24  90  95

# %%
df1.loc[::2,:]
# Out:
#              A   B   C   D
# 2019-06-20  38  59  76  92
# 2019-06-22  74  50  93  52
# 2019-06-24  90  70  95  25

# %%
df1
# Out:
#              A   B   C   D
# 2019-06-20  38  59  76  92
# 2019-06-21  37  85  55  76
# 2019-06-22  74  50  93  52
# 2019-06-23  61  24  56  81
# 2019-06-24  90  70  95  25

# %%
df1.loc['2019-06-22':'2019-06-24',['A','B']]
# Out:
#              A   B
# 2019-06-22  74  50
# 2019-06-23  61  24
# 2019-06-24  90  70

# %%
df
# Out:
#       name  maths  chemistry  physics     sex
# 1      ram   56.0       78.0     66.0    male
# 2     hari   78.0       89.0     77.0    male
# 3     jhon    0.0       78.0     88.0    male
# 4    alice   78.0        0.0     45.0  female
# 5      bob   68.0       56.0     67.0    male
# 6  natasha   89.0       76.0      0.0  female

# %%
newdf  = df.loc[:,['name','maths','physics']]

# %%
newdf
# Out:
#       name  maths  physics
# 1      ram   56.0     66.0
# 2     hari   78.0     77.0
# 3     jhon    0.0     88.0
# 4    alice   78.0     45.0
# 5      bob   68.0     67.0
# 6  natasha   89.0      0.0

# %%
newdf.sort_index(ascending=False)
# Out:
#       name  maths  physics
# 6  natasha   89.0      0.0
# 5      bob   68.0     67.0
# 4    alice   78.0     45.0
# 3     jhon    0.0     88.0
# 2     hari   78.0     77.0
# 1      ram   56.0     66.0

# %%
newdf.sort_index(axis=1,ascending=False)
# Out:
#    physics     name  maths
# 1     66.0      ram   56.0
# 2     77.0     hari   78.0
# 3     88.0     jhon    0.0
# 4     45.0    alice   78.0
# 5     67.0      bob   68.0
# 6      0.0  natasha   89.0

# %%
df
# Out:
#       name  maths  chemistry  physics     sex
# 1      ram   56.0       78.0     66.0    male
# 2     hari   78.0       89.0     77.0    male
# 3     jhon    0.0       78.0     88.0    male
# 4    alice   78.0        0.0     45.0  female
# 5      bob   68.0       56.0     67.0    male
# 6  natasha   89.0       76.0      0.0  female

# %%
ndf = df[['maths','chemistry','physics']]

# %%
ndf
# Out:
#    maths  chemistry  physics
# 1   56.0       78.0     66.0
# 2   78.0       89.0     77.0
# 3    0.0       78.0     88.0
# 4   78.0        0.0     45.0
# 5   68.0       56.0     67.0
# 6   89.0       76.0      0.0

# %%
ndf.sort_values(by="maths",ascending=False) # sort_value --> axis -> 0 column
# Out:
#    maths  chemistry  physics
# 6   89.0       76.0      0.0
# 2   78.0       89.0     77.0
# 4   78.0        0.0     45.0
# 5   68.0       56.0     67.0
# 1   56.0       78.0     66.0
# 3    0.0       78.0     88.0

# %%
ndf.loc[4,'chemistry'] = 95
# Out:
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
ndf
# Out:
#    maths  chemistry  physics
# 1   56.0       78.0     66.0
# 2   78.0       89.0     77.0
# 3    0.0       78.0     88.0
# 4   78.0       95.0     45.0
# 5   68.0       56.0     67.0
# 6   89.0       76.0      0.0

# %%
ndf.sort_values(by=["maths","chemistry"],ascending=False) # sort_value --> axis -> 0 column
# Out:
#    maths  chemistry  physics
# 6   89.0       76.0      0.0
# 4   78.0       95.0     45.0
# 2   78.0       89.0     77.0
# 5   68.0       56.0     67.0
# 1   56.0       78.0     66.0
# 3    0.0       78.0     88.0

# %%
ndf.T # wide to long , long to wide
# Out:
#               1     2     3     4     5     6
# maths      56.0  78.0   0.0  78.0  68.0  89.0
# chemistry  78.0  89.0  78.0  95.0  56.0  76.0
# physics    66.0  77.0  88.0  45.0  67.0   0.0

# %%
df
# Out:
#       name  maths  chemistry  physics     sex
# 1      ram   56.0       78.0     66.0    male
# 2     hari   78.0       89.0     77.0    male
# 3     jhon    0.0       78.0     88.0    male
# 4    alice   78.0        0.0     45.0  female
# 5      bob   68.0       56.0     67.0    male
# 6  natasha   89.0       76.0      0.0  female

# %%
df11 = df.pivot_table(columns="name")
df11
# Out:
# name       alice   bob  hari  jhon  natasha   ram
# chemistry    0.0  56.0  89.0  78.0     76.0  78.0
# maths       78.0  68.0  78.0   0.0     89.0  56.0
# physics     45.0  67.0  77.0  88.0      0.0  66.0

# %%
df11['timepass']  = np.array([1,2,3],dtype=float)

# %%
df11
# Out:
# name       alice   bob  hari  jhon  natasha   ram  timepass
# chemistry    0.0  56.0  89.0  78.0     76.0  78.0       1.0
# maths       78.0  68.0  78.0   0.0     89.0  56.0       2.0
# physics     45.0  67.0  77.0  88.0      0.0  66.0       3.0

# %%
df1
# Out:
#              A   B   C   D
# 2019-06-20  38  59  76  92
# 2019-06-21  37  85  55  76
# 2019-06-22  74  50  93  52
# 2019-06-23  61  24  56  81
# 2019-06-24  90  70  95  25

# %%
df1['E'] = np.random.randint(50,100,5)

# %%
df1
# Out:
#              A   B   C   D   E
# 2019-06-20  38  59  76  92  57
# 2019-06-21  37  85  55  76  89
# 2019-06-22  74  50  93  52  84
# 2019-06-23  61  24  56  81  85
# 2019-06-24  90  70  95  25  95

# %%
df1.loc['2019-06-25',:] = [ 50,60,66,77,65]

# %%
df1
# Out:
#                         A     B     C     D     E
# 2019-06-20 00:00:00  38.0  59.0  76.0  92.0  57.0
# 2019-06-21 00:00:00  37.0  85.0  55.0  76.0  89.0
# 2019-06-22 00:00:00  74.0  50.0  93.0  52.0  84.0
# 2019-06-23 00:00:00  61.0  24.0  56.0  81.0  85.0
# 2019-06-24 00:00:00  90.0  70.0  95.0  25.0  95.0
# 2019-06-25           50.0  60.0  66.0  77.0  65.0

# %%
df
# Out:
#       name  maths  chemistry  physics     sex
# 1      ram   56.0       78.0     66.0    male
# 2     hari   78.0       89.0     77.0    male
# 3     jhon    0.0       78.0     88.0    male
# 4    alice   78.0        0.0     45.0  female
# 5      bob   68.0       56.0     67.0    male
# 6  natasha   89.0       76.0      0.0  female

# %%
df1 = pd.DataFrame({
    'name':['ravi','jadu'],
    'maths':[66,77],
    'chemistry':[67,89],
    'physics':[66,77],
    'sex':['male','female']
})

# %%
df1
# Out:
#    name  maths  chemistry  physics     sex
# 0  ravi     66         67       66    male
# 1  jadu     77         89       77  female

# %%
df
# Out:
#       name  maths  chemistry  physics     sex
# 1      ram   56.0       78.0     66.0    male
# 2     hari   78.0       89.0     77.0    male
# 3     jhon    0.0       78.0     88.0    male
# 4    alice   78.0        0.0     45.0  female
# 5      bob   68.0       56.0     67.0    male
# 6  natasha   89.0       76.0      0.0  female

# %%
new_df = pd.concat([df,df1])
new_df
# Out:
#       name  maths  chemistry  physics     sex
# 1      ram   56.0       78.0     66.0    male
# 2     hari   78.0       89.0     77.0    male
# 3     jhon    0.0       78.0     88.0    male
# 4    alice   78.0        0.0     45.0  female
# 5      bob   68.0       56.0     67.0    male
# 6  natasha   89.0       76.0      0.0  female
# 0     ravi   66.0       67.0     66.0    male
# 1     jadu   77.0       89.0     77.0  female

# %%
new_df.index = range(1,9)

# %%
new_df
# Out:
#       name  maths  chemistry  physics     sex
# 1      ram   56.0       78.0     66.0    male
# 2     hari   78.0       89.0     77.0    male
# 3     jhon    0.0       78.0     88.0    male
# 4    alice   78.0        0.0     45.0  female
# 5      bob   68.0       56.0     67.0    male
# 6  natasha   89.0       76.0      0.0  female
# 7     ravi   66.0       67.0     66.0    male
# 8     jadu   77.0       89.0     77.0  female

# %%
student = pd.DataFrame({
    'sid' : [ 231,232,233,234,235],
    'name': ['jhon','riya','rahul','sweety','raj'],
    'age' : [ 18,21,25,16,17]
})

# %%
student
# Out:
#    sid    name  age
# 0  231    jhon   18
# 1  232    riya   21
# 2  233   rahul   25
# 3  234  sweety   16
# 4  235     raj   17

# %%
cricket = pd.DataFrame({
    'sid': [ 231,232,234,235,236,240],
    'player' : pd.Categorical(['wk','bat','ball','bat','bat','all']),
    'performance' : [ 5.7,6.3,7.0,8.0,3.6,7.2]
})

# %%
cricket
# Out:
#    sid player  performance
# 0  231     wk          5.7
# 1  232    bat          6.3
# 2  234   ball          7.0
# 3  235    bat          8.0
# 4  236    bat          3.6
# 5  240    all          7.2

# %%
football = pd.DataFrame({
    'id' : [ 231,235,233,240],
    'pos' : pd.Categorical([ 'center','gk','defence','attack'])
})

# %%
football
# Out:
#     id      pos
# 0  231   center
# 1  235       gk
# 2  233  defence
# 3  240   attack

# %%
student
# Out:
#    sid    name  age
# 0  231    jhon   18
# 1  232    riya   21
# 2  233   rahul   25
# 3  234  sweety   16
# 4  235     raj   17

# %%
cricket
# Out:
#    sid player  performance
# 0  231     wk          5.7
# 1  232    bat          6.3
# 2  234   ball          7.0
# 3  235    bat          8.0
# 4  236    bat          3.6
# 5  240    all          7.2

# %%
x = pd.merge(student,cricket,on="sid")

# %%
x
# Out:
#    sid    name  age player  performance
# 0  231    jhon   18     wk          5.7
# 1  232    riya   21    bat          6.3
# 2  234  sweety   16   ball          7.0
# 3  235     raj   17    bat          8.0

# %%
y = pd.merge(student,cricket,on="sid",how='left')
y
# Out:
#    sid    name  age player  performance
# 0  231    jhon   18     wk          5.7
# 1  232    riya   21    bat          6.3
# 2  233   rahul   25    NaN          NaN
# 3  234  sweety   16   ball          7.0
# 4  235     raj   17    bat          8.0

# %%
y = pd.merge(student,cricket,on="sid",how='right')
y
# Out:
#    sid    name   age player  performance
# 0  231    jhon  18.0     wk          5.7
# 1  232    riya  21.0    bat          6.3
# 2  234  sweety  16.0   ball          7.0
# 3  235     raj  17.0    bat          8.0
# 4  236     NaN   NaN    bat          3.6
# 5  240     NaN   NaN    all          7.2

# %%
cricket
# Out:
#    sid player  performance
# 0  231     wk          5.7
# 1  232    bat          6.3
# 2  234   ball          7.0
# 3  235    bat          8.0
# 4  236    bat          3.6
# 5  240    all          7.2

# %%
football
# Out:
#     id      pos
# 0  231   center
# 1  235       gk
# 2  233  defence
# 3  240   attack

# %%
z = pd.merge(cricket,football,left_on='sid',right_on='id')

# %%
z
# Out:
#    sid player  performance   id     pos
# 0  231     wk          5.7  231  center
# 1  235    bat          8.0  235      gk
# 2  240    all          7.2  240  attack

# %%
p = z.join(student,how='left',lsuffix='_id')

# %%
p
# Out:
#    sid_id player  performance   id     pos  sid   name  age
# 0     231     wk          5.7  231  center  231   jhon   18
# 1     235    bat          8.0  235      gk  232   riya   21
# 2     240    all          7.2  240  attack  233  rahul   25

# %%
x
# Out:
#    sid    name  age player  performance
# 0  231    jhon   18     wk          5.7
# 1  232    riya   21    bat          6.3
# 2  234  sweety   16   ball          7.0
# 3  235     raj   17    bat          8.0

# %%
df
# Out:
#       name  maths  chemistry  physics     sex
# 1      ram   56.0       78.0     66.0    male
# 2     hari   78.0       89.0     77.0    male
# 3     jhon    0.0       78.0     88.0    male
# 4    alice   78.0        0.0     45.0  female
# 5      bob   68.0       56.0     67.0    male
# 6  natasha   89.0       76.0      0.0  female

# %%
df.query("maths > 60 and physics > 60")
# Out:
#    name  maths  chemistry  physics   sex
# 2  hari   78.0       89.0     77.0  male
# 5   bob   68.0       56.0     67.0  male

# %%
df[(df['maths'] > 60)&(df['physics']>60)]
# Out:
#    name  maths  chemistry  physics   sex
# 2  hari   78.0       89.0     77.0  male
# 5   bob   68.0       56.0     67.0  male
