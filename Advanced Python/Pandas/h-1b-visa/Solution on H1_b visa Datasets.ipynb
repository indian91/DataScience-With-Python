# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('h1b_kaggle.csv')

# %%
df.shape
# Out:
# (3002458, 11)

# %%
df1=df[:30000]

# %%
df1.to_csv('h1b.csv')

# %%
df=pd.read_csv('h1b.csv')

# %%
df.shape
# Out:
# (30000, 12)

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1          CASE_STATUS  \
# 0           0             1  CERTIFIED-WITHDRAWN
# 1           1             2  CERTIFIED-WITHDRAWN
# 2           2             3  CERTIFIED-WITHDRAWN
# 3           3             4  CERTIFIED-WITHDRAWN
# 4           4             5            WITHDRAWN
#
#                                        EMPLOYER_NAME  \
# 0                             UNIVERSITY OF MICHIGAN
# 1                             GOODMAN NETWORKS, INC.
# 2                          PORTS AMERICA GROUP, INC.
# 3  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# ...

# %%
df.drop(['Unnamed: 0','Unnamed: 0.1'],axis=1,inplace=True)

# %%
df.drop(['lon','lat'],axis=1,inplace=True)

# %%
df.head()
# Out:
#            CASE_STATUS                                      EMPLOYER_NAME  \
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4            WITHDRAWN                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
#   FULL_TIME_POSITION  PREVAILING_WAGE    YEAR                 WORKSITE
# ...

# %%
df.rename({
    'CASE_STATUS':'status','EMPLOYER_NAME':'company','SOC_NAME':'Dn','JOB_TILTE':'job_type','FULL_TIME_POSITION':'full_time','PREVAILING_WAGE':'salary',
},inplace=True,axis=1)

# %%
df.head()
# Out:
#                 status                                            company  \
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4            WITHDRAWN                          PEABODY INVESTMENTS CORP.
#
#                               Dn                     JOB_TITLE full_time  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW         N
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER         Y
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER         Y
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS         Y
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA         Y
#
#      salary    YEAR                 WORKSITE
# ...

# %%
df.groupby('status')['status'].value_counts()
# Out:
# status               status
# CERTIFIED            CERTIFIED              25562
# CERTIFIED-WITHDRAWN  CERTIFIED-WITHDRAWN     2319
# DENIED               DENIED                   920
# WITHDRAWN            WITHDRAWN               1199
# Name: status, dtype: int64

# %%
df['company'].value_counts().sort_values(ascending=False).head(15).plot(kind='bar',title='top 15 hiring company')

# %%
df['salary'].value_counts().sort_values(ascending=False).head(10).plot(kind='bar')

# %%
len(df)
# Out:
# 30000

# %%
df1=pd.Series(x for x in range(30000))

# %%
len(df1)
# Out:
# 30000

# %%
df.tail()
# Out:
#           status                     company                   Dn  \
# 29995  CERTIFIED  ERNST &AMP; YOUNG U.S. LLP  MANAGEMENT ANALYSTS
# 29996  CERTIFIED       MICROSOFT CORPORATION  MANAGEMENT ANALYSTS
# 29997  CERTIFIED  ERNST &AMP; YOUNG U.S. LLP  MANAGEMENT ANALYSTS
# 29998  CERTIFIED               ACCENTURE LLP  MANAGEMENT ANALYSTS
# 29999  CERTIFIED       VENSOFT SOLUTIONS INC  MANAGEMENT ANALYSTS
#
#                         JOB_TITLE full_time   salary    YEAR  \
# 29995             ADVISORY SENIOR         N  53352.0  2016.0
# 29996  OPERATIONS PROGRAM MANAGER         Y  71531.0  2016.0
# 29997            ADVISORY MANAGER         Y  79934.0  2016.0
# 29998                  CONSULTANT         N  69243.0  2016.0
# 29999       MANAGEMENT CONSULTANT         N  53165.0  2016.0
#
#                          WORKSITE
# 29995  GREENVILLE, SOUTH CAROLINA
# 29996                RENO, NEVADA
# 29997              TAMPA, FLORIDA
# 29998       OVERLAND PARK, KANSAS
# ...

# %%
df2=pd.concat([df1,df],axis=1)

# %%
df2.head()
# Out:
#    0               status                                            company  \
# 0  0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1  1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4  4            WITHDRAWN                          PEABODY INVESTMENTS CORP.
#
#                               Dn                     JOB_TITLE full_time  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW         N
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER         Y
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER         Y
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS         Y
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA         Y
#
#      salary    YEAR                 WORKSITE
# ...

# %%
df=df2.rename({0:'id'},axis=1)

# %%
df.head()
# Out:
#    id               status                                            company  \
# 0   0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1   1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2   2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3   3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4   4            WITHDRAWN                          PEABODY INVESTMENTS CORP.
#
#                               Dn                     JOB_TITLE full_time  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW         N
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER         Y
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER         Y
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS         Y
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA         Y
#
#      salary    YEAR                 WORKSITE
# ...

# %%
df[df['status']=='CERTIFIED'].groupby('WORKSITE')['id'].count()
# Out:
# WORKSITE
# 1017 S. MOUNTAIN AVENUE, CALIFORNIA     1
# 2401 GREEN LAWN BLVD., TEXAS            1
# ABBOTT PARK, ILLINOIS                   6
# ABERDEEN, SOUTH DAKOTA                  1
# ABILENE, TEXAS                          1
# ACTON, MASSACHUSETTS                    5
# ACWORTH, GEORGIA                        3
# ADA, MICHIGAN                           2
# ADAIRSVILLE, GEORGIA                    1
# ADDISON, ILLINOIS                       4
# ADDISON, TEXAS                         14
# AGAWAM, MASSACHUSETTS                   1
# AGOURA HILLS, CALIFORNIA                4
# AGUADILLA, PUERTO RICO                  1
# AHOSKIE, NORTH CAROLINA                 8
# AKRON, NEW YORK                         1
# AKRON, OHIO                             7
# ALAMEDA, CALIFORNIA                    12
# ALBANY, CALIFORNIA                      1
# ALBANY, GEORGIA                         1
# ALBANY, NEW YORK                       20
# ALBANY, OREGON                          1
# ...

# %%
df[df['status']=='CERTIFIED'].groupby('salary')['id'].count().sort_values(ascending=False).head(10)
# Out:
# salary
# 106746.0    175
# 138133.0    156
# 108493.0    132
# 55973.0     121
# 118414.0    120
# 51376.0     117
# 145725.0    105
# 128294.0    103
# 227178.0    102
# 74402.0     102
# Name: id, dtype: int64

# %%
df[df['status']=='CERTIFIED'].groupby('WORKSITE')['id'].count().sort_values(ascending=False).head(20)
# Out:
# WORKSITE
# NEW YORK, NEW YORK                  2893
# SAN FRANCISCO, CALIFORNIA           1039
# HOUSTON, TEXAS                       846
# CHICAGO, ILLINOIS                    567
# SEATTLE, WASHINGTON                  514
# ATLANTA, GEORGIA                     412
# LOS ANGELES, CALIFORNIA              406
# SAN JOSE, CALIFORNIA                 382
# MIAMI, FLORIDA                       319
# DALLAS, TEXAS                        300
# BOSTON, MASSACHUSETTS                273
# PALO ALTO, CALIFORNIA                229
# SUNNYVALE, CALIFORNIA                226
# AUSTIN, TEXAS                        220
# MOUNTAIN VIEW, CALIFORNIA            217
# SANTA CLARA, CALIFORNIA              208
# PHOENIX, ARIZONA                     192
# WASHINGTON, DISTRICT OF COLUMBIA     171
# REDMOND, WASHINGTON                  167
# JERSEY CITY, NEW JERSEY              159
# Name: id, dtype: int64

# %%
df[df['status']=='CERTIFIED'].groupby('WORKSITE')['id'].count().sort_values(ascending=False).head(20).plot(kind='bar')

# %%
df[df['status']=='DENIED'].groupby('WORKSITE')['id'].count().sort_values(ascending=False).head(10)
# Out:
# WORKSITE
# NEW YORK, NEW YORK                  117
# HOUSTON, TEXAS                       28
# SAN FRANCISCO, CALIFORNIA            25
# LOS ANGELES, CALIFORNIA              24
# BROOKLYN, NEW YORK                   18
# WASHINGTON, DISTRICT OF COLUMBIA     17
# ATLANTA, GEORGIA                     16
# CHICAGO, ILLINOIS                    14
# SAN JOSE, CALIFORNIA                 13
# BOSTON, MASSACHUSETTS                13
# Name: id, dtype: int64

# %%
df['salary'].sort_values(ascending=False).head(20)
# Out:
# 5579     329139200.0
# 10954    259496640.0
# 19772    251796480.0
# 24144     88431200.0
# 1701      72800000.0
# 25928      3081468.0
# 397        2648400.0
# 16045      1016748.0
# 941         780000.0
# 16278       753288.0
# 547         631700.0
# 24239       425151.0
# 569         292000.0
# 570         292000.0
# 540         289640.0
# 576         284211.0
# 563         284211.0
# 573         284211.0
# 590         284211.0
# 533         283500.0
# Name: salary, dtype: float64

# %%
df['salary'].sort_values(ascending=False).head(20).plot(kind='bar')

# %%
df.dropna(how='all')
# Out:
#           id               status  \
# 0          0  CERTIFIED-WITHDRAWN
# 1          1  CERTIFIED-WITHDRAWN
# 2          2  CERTIFIED-WITHDRAWN
# 3          3  CERTIFIED-WITHDRAWN
# 4          4            WITHDRAWN
# 5          5  CERTIFIED-WITHDRAWN
# 6          6  CERTIFIED-WITHDRAWN
# 7          7  CERTIFIED-WITHDRAWN
# 8          8  CERTIFIED-WITHDRAWN
# 9          9            WITHDRAWN
# 10        10  CERTIFIED-WITHDRAWN
# 11        11  CERTIFIED-WITHDRAWN
# 12        12  CERTIFIED-WITHDRAWN
# 13        13  CERTIFIED-WITHDRAWN
# 14        14  CERTIFIED-WITHDRAWN
# 15        15  CERTIFIED-WITHDRAWN
# 16        16  CERTIFIED-WITHDRAWN
# 17        17  CERTIFIED-WITHDRAWN
# 18        18            CERTIFIED
# 19        19            CERTIFIED
# 20        20  CERTIFIED-WITHDRAWN
# 21        21  CERTIFIED-WITHDRAWN
# 22        22            CERTIFIED
# 23        23            CERTIFIED
# 24        24  CERTIFIED-WITHDRAWN
# 25        25            CERTIFIED
# ...

# %%
df.shape
# Out:
# (30000, 9)

# %%
df[df['full_time']=='Y']['full_time'].count()
# Out:
# 20813

# %%
df[df['full_time']=='N']['full_time'].count()
# Out:
# 9187

# %%
df[df['Dn']=='CHIEF EXECUTIVES']['Dn'].count()
# Out:
# 593

# %%
df['Dn'].value_counts().head(25)
# Out:
# COMPUTER AND INFORMATION SYSTEMS MANAGERS             6190
# MARKETING MANAGERS                                    2884
# MANAGEMENT ANALYSTS                                   2197
# GENERAL AND OPERATIONS MANAGERS                       1998
# FINANCIAL MANAGERS                                    1808
# LOGISTICIANS                                          1722
# HUMAN RESOURCES SPECIALISTS                           1376
# ARCHITECTURAL AND ENGINEERING MANAGERS                1283
# SALES MANAGERS                                        1076
# COMPLIANCE OFFICERS                                    823
# MANAGERS, ALL OTHER                                    798
# COST ESTIMATORS                                        762
# MEDICAL AND HEALTH SERVICES MANAGERS                   761
# INDUSTRIAL PRODUCTION MANAGERS                         684
# CONSTRUCTION MANAGERS                                  612
# CHIEF EXECUTIVES                                       593
# ...

# %%
df['Dn'].value_counts().head(25).plot(kind='bar')
