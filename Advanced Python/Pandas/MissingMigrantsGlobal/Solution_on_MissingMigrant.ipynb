# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('MissingMigrantsGlobal.csv',sep='\t',encoding='latin')

# %%
df.head()
# Out:
#    Web ID Region of Incident   Reported Date  Reported Year Reported Month  \
# 0   51591      Mediterranean  March 28, 2019           2019            Mar
# 1   51588      Mediterranean  March 26, 2019           2019            Mar
# 2   51589      Mediterranean  March 26, 2019           2019            Mar
# 3   51590      Mediterranean  March 26, 2019           2019            Mar
# 4   51587    Central America  March 25, 2019           2019            Mar
#
#    Number Dead  Minimum Estimated Number of Missing  Total Dead and Missing  \
# 0          NaN                                  2.0                       2
# 1          4.0                                  NaN                       4
# 2          1.0                                  NaN                       1
# 3          1.0                                  NaN                       1
# 4          1.0                                  NaN                       1
#
# ...

# %%
df.drop(['Reported Year','Reported Month','URL','UNSD Geographical Grouping','Source Quality'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Web ID Region of Incident   Reported Date  Number Dead  \
# 0   51591      Mediterranean  March 28, 2019          NaN
# 1   51588      Mediterranean  March 26, 2019          4.0
# 2   51589      Mediterranean  March 26, 2019          1.0
# 3   51590      Mediterranean  March 26, 2019          1.0
# 4   51587    Central America  March 25, 2019          1.0
#
#    Minimum Estimated Number of Missing  Total Dead and Missing  \
# 0                                  2.0                       2
# 1                                  NaN                       4
# 2                                  NaN                       1
# 3                                  NaN                       1
# 4                                  NaN                       1
#
#    Number of Survivors  Number of Females  Number of Males  \
# 0                 36.0                NaN              2.0
# 1                 11.0                3.0              NaN
# ...

# %%
df.drop('Location Coordinates',axis=1,inplace=True)

# %%
df.head()
# Out:
#    Web ID Region of Incident   Reported Date  Number Dead  \
# 0   51591      Mediterranean  March 28, 2019          NaN
# 1   51588      Mediterranean  March 26, 2019          4.0
# 2   51589      Mediterranean  March 26, 2019          1.0
# 3   51590      Mediterranean  March 26, 2019          1.0
# 4   51587    Central America  March 25, 2019          1.0
#
#    Minimum Estimated Number of Missing  Total Dead and Missing  \
# 0                                  2.0                       2
# 1                                  NaN                       4
# 2                                  NaN                       1
# 3                                  NaN                       1
# 4                                  NaN                       1
#
#    Number of Survivors  Number of Females  Number of Males  \
# 0                 36.0                NaN              2.0
# 1                 11.0                3.0              NaN
# ...

# %%
df.shape
# Out:
# (5333, 14)

# %%
df.drop('Information Source',axis=1,inplace=True)

# %%
df.head()
# Out:
#    Web ID Region of Incident   Reported Date  Number Dead  \
# 0   51591      Mediterranean  March 28, 2019          NaN
# 1   51588      Mediterranean  March 26, 2019          4.0
# 2   51589      Mediterranean  March 26, 2019          1.0
# 3   51590      Mediterranean  March 26, 2019          1.0
# 4   51587    Central America  March 25, 2019          1.0
#
#    Minimum Estimated Number of Missing  Total Dead and Missing  \
# 0                                  2.0                       2
# 1                                  NaN                       4
# 2                                  NaN                       1
# 3                                  NaN                       1
# 4                                  NaN                       1
#
#    Number of Survivors  Number of Females  Number of Males  \
# 0                 36.0                NaN              2.0
# 1                 11.0                3.0              NaN
# ...

# %%
df.drop('Location Description',axis=1,inplace=True)

# %%
df.head()
# Out:
#    Web ID Region of Incident   Reported Date  Number Dead  \
# 0   51591      Mediterranean  March 28, 2019          NaN
# 1   51588      Mediterranean  March 26, 2019          4.0
# 2   51589      Mediterranean  March 26, 2019          1.0
# 3   51590      Mediterranean  March 26, 2019          1.0
# 4   51587    Central America  March 25, 2019          1.0
#
#    Minimum Estimated Number of Missing  Total Dead and Missing  \
# 0                                  2.0                       2
# 1                                  NaN                       4
# 2                                  NaN                       1
# 3                                  NaN                       1
# 4                                  NaN                       1
#
#    Number of Survivors  Number of Females  Number of Males  \
# 0                 36.0                NaN              2.0
# 1                 11.0                3.0              NaN
# ...

# %%
df.shape
# Out:
# (5333, 12)

# %%
df.dropna(how='all',axis=0,inplace=True)

# %%
df.shape
# Out:
# (5333, 12)

# %% [markdown]
#  1.What are the Top 10 Region of Incidents with higher incidents?

# %%
d=df['Region of Incident'].value_counts().head(10)

# %%
df['Region of Incident'].value_counts().head(10).plot(kind='bar',title='Top 10 Region of Accident')

# %%
df.fillna({'Number Dead':0,'Minimum Estimated Number of Missing':0,'Total Dead and Missing':0,'Number of Survivors':0,'Number of Males':0,'Number of Females':0,'Number of Children':0},inplace=True)

# %%
l=[]
for var in df['Number of Children']:
    l.append(int(var))
x=pd.Series(l)   
df['Number of Children'] = x

# %%
l=[1,23,4,4,5,5]
pd.Series(l)
# Out:
# 0     1
# 1    23
# 2     4
# 3     4
# 4     5
# 5     5
# dtype: int64

# %%
df.head(3)
# Out:
#    Web ID Region of Incident   Reported Date  Number Dead  \
# 0   51591      Mediterranean  March 28, 2019            0
# 1   51588      Mediterranean  March 26, 2019            4
# 2   51589      Mediterranean  March 26, 2019            1
#
#    Minimum Estimated Number of Missing  Total Dead and Missing  \
# 0                                    2                       2
# 1                                    0                       4
# 2                                    0                       1
#
#    Number of Survivors  Number of Females  Number of Males  \
# 0                   36                  0                2
# 1                   11                  3                0
# 2                    0                  0                0
#
#    Number of Children     Cause of Death        Migration Route
# 0                   0  Presumed drowning  Eastern Mediterranean
# 1                   1  Presumed drowning  Eastern Mediterranean
# ...

# %% [markdown]
# 2.What is the Percentage of missing Females, Males and Children in top 10 regions of incidents?

# %%
df1=df.groupby('Region of Incident')['Total Dead and Missing'].count().sort_values(ascending=False)

# %%
df2=df.groupby('Region of Incident')['Number of Females'].count().sort_values(ascending=False)

# %%
df2
# Out:
# Region of Incident
# US-Mexico Border      1337
# North Africa          1239
# Mediterranean          984
# Sub-Saharan Africa     475
# Central America        309
# Europe                 249
# Horn of Africa         235
# Middle East            164
# South Asia             151
# Southeast Asia          96
# Caribbean               59
# South America           28
# East Asia                5
# North America            1
# Central Asia             1
# Name: Number of Females, dtype: int64

# %%
df[['Number of Females','Number of Males','Number of Children']].apply(lambda x: sum(x))
# Out:
# Number of Females     1805
# Number of Males       5319
# Number of Children    1595
# dtype: int64

# %%
df['Total Dead and Missing'].sum()
# Out:
# 31552

# %%
d = df.groupby('Region of Incident').count().sort_values(by="Web ID",ascending=False)

# %%
d
# Out:
#                     Web ID  Reported Date  Number Dead  \
# Region of Incident
# US-Mexico Border      1337           1337         1337
# North Africa          1239           1239         1239
# Mediterranean          984            984          984
# Sub-Saharan Africa     475            475          475
# Central America        309            309          309
# Europe                 249            249          249
# Horn of Africa         235            235          235
# Middle East            164            164          164
# South Asia             151            151          151
# Southeast Asia          96             96           96
# Caribbean               59             59           59
# South America           28             28           28
# East Asia                5              5            5
# Central Asia             1              1            1
# North America            1              1            1
#
#                     Minimum Estimated Number of Missing  \
# ...

# %%
df[['Number of Children','Number of Females','Number of Males']].sum()
# Out:
# Number of Children    1595
# Number of Females     1805
# Number of Males       5319
# dtype: int64

# %%
df.groupby('Region of Incident')['Cause of Death'].max().value_counts()
# Out:
# Violence                                   6
# Vehicle Accident                           2
# Violence while attempting to board boat    1
# Vehicle Accident, Shot or stabbed          1
# Presumed drowning                          1
# Violence, Rape                             1
# Hypothermia                                1
# Violence, Asphyxiation, Drowning           1
# Bus fire                                   1
# Name: Cause of Death, dtype: int64

# %%
df=pd.read_csv('MissingMigrantsGlobal.csv',sep='\t',encoding='latin')

# %%
df.head()
# Out:
#    Web ID Region of Incident   Reported Date  Reported Year Reported Month  \
# 0   51591      Mediterranean  March 28, 2019           2019            Mar
# 1   51588      Mediterranean  March 26, 2019           2019            Mar
# 2   51589      Mediterranean  March 26, 2019           2019            Mar
# 3   51590      Mediterranean  March 26, 2019           2019            Mar
# 4   51587    Central America  March 25, 2019           2019            Mar
#
#    Number Dead  Minimum Estimated Number of Missing  Total Dead and Missing  \
# 0          NaN                                  2.0                       2
# 1          4.0                                  NaN                       4
# 2          1.0                                  NaN                       1
# 3          1.0                                  NaN                       1
# 4          1.0                                  NaN                       1
#
# ...

# %%
df.groupby('Region of Incident')['Information Source'].count()
# Out:
# Region of Incident
# Caribbean               59
# Central America        309
# Central Asia             1
# East Asia                5
# Europe                 249
# Horn of Africa         235
# Mediterranean          984
# Middle East            164
# North Africa          1239
# North America            1
# South America           28
# South Asia             151
# Southeast Asia          95
# Sub-Saharan Africa     475
# US-Mexico Border      1336
# Name: Information Source, dtype: int64

# %%
df[df['Reported Year']==2018].groupby('Reported Month')['Reported Month'].count()
# Out:
# Reported Month
# Apr    126
# Aug    143
# Dec     58
# Feb    120
# Jan    117
# Jul    157
# Jun    176
# Mar    123
# May    131
# Nov     82
# Oct    134
# Sep    139
# Name: Reported Month, dtype: int64

# %%
df[df['Reported Year']==2018].groupby('Reported Month')['Reported Month'].count().plot(kind='bar')

# %%
df['Migration Route'].value_counts()
# Out:
# Central America to US                        1507
# Central Mediterranean                         499
# Western Mediterranean                         255
# Eastern Mediterranean                         230
# Western Balkans                                64
# Calais to United Kingdom                       51
# Western African                                15
# Horn Africa to Yemen                           15
# Italy to France                                 9
# Darien Gap                                      7
# Caribbean to Central America                    3
# Dominican Republic to Puerto Rico               2
# Venezuela to Curaçao                            1
# Malaysia to Indonesia                           1
# From Haiti to Dajabon, Dominican Republic       1
# Name: Migration Route, dtype: int64

# %%
df['Migration Route'].value_counts().plot(kind='bar')

# %%
df['Migration Route'].value_counts()
# Out:
# 2018    1506
# 2017    1356
# 2016    1275
# 2015     808
# 2014     245
# 2019     143
# Name: Reported Year, dtype: int64

# %%
df['Migration Route'].value_counts().plot(kind='bar')

# %%
df1=df['Migration Route'].value_counts()

# %%
df1
# Out:
# Central America to US                        1507
# Central Mediterranean                         499
# Western Mediterranean                         255
# Eastern Mediterranean                         230
# Western Balkans                                64
# Calais to United Kingdom                       51
# Western African                                15
# Horn Africa to Yemen                           15
# Italy to France                                 9
# Darien Gap                                      7
# Caribbean to Central America                    3
# Dominican Republic to Puerto Rico               2
# Venezuela to Curaçao                            1
# Malaysia to Indonesia                           1
# From Haiti to Dajabon, Dominican Republic       1
# Name: Migration Route, dtype: int64

# %%
df['Reported Year'].value_counts()
# Out:
# 2018    1506
# 2017    1356
# 2016    1275
# 2015     808
# 2014     245
# 2019     143
# Name: Reported Year, dtype: int64
